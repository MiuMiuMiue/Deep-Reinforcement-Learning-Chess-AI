# %% [markdown]
# ### Environment Set Up (Download and Install Python 3.9 and corresponding Torch packages).

# %%
# !sudo update-alternatives --config python3
# Out:
# update-alternatives: error: no alternatives for python3

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.9 python3.9-dev python3.9-distutils libpython3.9-dev

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1

# %%
# !sudo apt install python3-pip

# %%
# !python3 --version

# %%
# !pip --version

# %%
# !pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 torchaudio===0.10.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %% [markdown]
# ### Following 3 cells are only for users who run in Google Colab

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/MiuMiuMiue/Deep-Reinforcement-Learning-Chess-AI.git

# %%
# cd to the project directory

% cd .....

# %% [markdown]
# ### Following 2 cells are required for all users to download necessary packages.

# %%
# !pip install -r requirements.txt

# %%
# !pip install ipykernel

# %% [markdown]
# ### Commands to run each file

# %% [markdown]
# Training the model

# %%
# !python train.py --agent double --ckpt results/DoubleAgents/model_ckpts --start-episode 735 --episodes 1000

# %% [markdown]
# Evaluating the model

# %%
# !python playGames.py

# %% [markdown]
# Plot the learning curves

# %%
# !python3 plot.py
# Out:
# Double Agents ...
# Single Agent ...
