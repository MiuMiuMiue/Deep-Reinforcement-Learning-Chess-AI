# %%
# !sudo update-alternatives --config python3
# Out:
# update-alternatives: error: no alternatives for python3

# %%
# !sudo apt-get update -y
# !sudo apt-get install python3.9 python3.9-dev python3.9-distutils libpython3.9-dev

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.9 1

# %%
# !sudo apt install python3-pip

# %%
# !python3 --version

# %%
# !pip --version

# %%
# !pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 torchaudio===0.10.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/UCI_documents/CS_175/betaChess/Deep-Reinforcement-Learning-Chess-AI

# %%
# !git pull

# %%
# !git checkout double_agent_training

# %%
# !pip install -r requirements.txt

# %%
# !pip install ipykernel

# %%
# !python train.py --agent double --ckpt results/DoubleAgents/model_ckpts --start-episode 735 --episodes 1000

# %%
# !python testing.py

# %%
# !ls
# Out:
# agents	chess	    learnings  README.md	 results     train.py
# buffer	envtest.py  plot.py    requirements.txt  testing.py  utils

# %%
# !python3 plot.py
# Out:
# Double Agents ...
# Single Agent ...
